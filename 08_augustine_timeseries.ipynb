# %% [markdown]
# # Augustine Tilt Timeseries

# %%
import obspy
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

import events

matplotlib.rc('pdf', fonttype=42)

plt.style.use("/home/mchristo/proj/libmsc/style/msc.mplstyle")

# %% [markdown]
# ## Download data with pysep and estimate tilt

# %%
#!pysep -o -c ./data/augustine2006_1to2.yaml
#!pysep -o -c ./data/augustine2006_3to8.yaml
#!pysep -o -c ./augustine2006_9.yaml
#!pysep -c -c ./augustine2006_10to13.yaml

#!mv *SOUTHERN* data/seis

# %%
#!seinei -v -a -f 2 -pbl 43200 -pbs 120 ./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/inv.xml ./data/seis/*SOUTHERN*/SAC/20*.sac
# Out:
# Reading inventory file:
# 	./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/inv.xml
# Reading SAC file(s):
# 	./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/SAC/2006-01-11T140000_SOUTHERN_ALASKA.AV.AU11..HHE.sac
# 	./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/SAC/2006-01-11T140000_SOUTHERN_ALASKA.AV.AU11..HHN.sac
# 	./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/SAC/2006-01-11T140000_SOUTHERN_ALASKA.AV.AU12..HHE.sac
# 	./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/SAC/2006-01-11T140000_SOUTHERN_ALASKA.AV.AU12..HHN.sac
# 	./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/SAC/2006-01-11T140000_SOUTHERN_ALASKA.AV.AU13..HHE.sac
# 	./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/SAC/2006-01-11T140000_SOUTHERN_ALASKA.AV.AU13..HHN.sac
# 	./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/SAC/2006-01-11T140000_SOUTHERN_ALASKA.AV.AU14..HHE.sac
# 	./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/SAC/2006-01-11T140000_SOUTHERN_ALASKA.AV.AU14..HHN.sac
# 	./data/seis/2006-01-14T000000_SOUTHERN_ALASKA/SAC/2006-01-14T000000_SOUTHERN_ALASKA.AV.AU11..HHE.sac
# 	./data/seis/2006-01-14T000000_SOUTHERN_ALASKA/SAC/2006-01-14T000000_SOUTHERN_ALASKA.AV.AU11..HHN.sac
# 	./data/seis/2006-01-14T000000_SOUTHERN_ALASKA/SAC/2006-01-14T000000_SOUTHERN_ALASKA.AV.AU12..HHE.sac
# 	./data/seis/2006-01-14T000000_SOUTHERN_ALASKA/SAC/2006-01-14T000000_SOUTHERN_ALASKA.AV.AU12..HHN.sac
# 	./data/seis/2006-01-14T000000_SOUTHERN_ALASKA/SAC/2006-01-14T000000_SOUTHERN_ALASKA.AV.AU13..HHE.sac
# 	./data/seis/2006-01-14T000000_SOUTHERN_ALASKA/SAC/2006-01-14T000000_SOUTHERN_ALASKA.AV.AU13..HHN.sac
# 	./data/seis/2006-01-14T000000_SOUTHERN_ALASKA/SAC/2006-01-14T000000_SOUTHERN_ALASKA.AV.AU14..HHE.sac
# 	./data/seis/2006-01-14T000000_SOUTHERN_ALASKA/SAC/2006-01-14T000000_SOUTHERN_ALASKA.AV.AU14..HHN.sac
# 	./data/seis/2006-01-17T170000_SOUTHERN_ALASKA/SAC/2006-01-17T170000_SOUTHERN_ALASKA.AV.AU11..HHE.sac
# 	./data/seis/2006-01-17T170000_SOUTHERN_ALASKA/SAC/2006-01-17T170000_SOUTHERN_ALASKA.AV.AU11..HHN.sac
# 	./data/seis/2006-01-17T170000_SOUTHERN_ALASKA/SAC/2006-01-17T170000_SOUTHERN_ALASKA.AV.AU12..HHE.sac
# 	./data/seis/2006-01-17T170000_SOUTHERN_ALASKA/SAC/2006-01-17T170000_SOUTHERN_ALASKA.AV.AU12..HHN.sac
# 	./data/seis/2006-01-17T170000_SOUTHERN_ALASKA/SAC/2006-01-17T170000_SOUTHERN_ALASKA.AV.AU13..HHE.sac
# 	./data/seis/2006-01-17T170000_SOUTHERN_ALASKA/SAC/2006-01-17T170000_SOUTHERN_ALASKA.AV.AU13..HHN.sac
# 	./data/seis/2006-01-17T170000_SOUTHERN_ALASKA/SAC/2006-01-17T170000_SOUTHERN_ALASKA.AV.AU14..HHE.sac
# 	./data/seis/2006-01-17T170000_SOUTHERN_ALASKA/SAC/2006-01-17T170000_SOUTHERN_ALASKA.AV.AU14..HHN.sac
# 	./data/seis/2006-01-28T120000_SOUTHERN_ALASKA/SAC/2006-01-28T120000_SOUTHERN_ALASKA.AV.AU11..HHE.sac
# 	./data/seis/2006-01-28T120000_SOUTHERN_ALASKA/SAC/2006-01-28T120000_SOUTHERN_ALASKA.AV.AU11..HHN.sac
# 	./data/seis/2006-01-28T120000_SOUTHERN_ALASKA/SAC/2006-01-28T120000_SOUTHERN_ALASKA.AV.AU12..HHE.sac
# 	./data/seis/2006-01-28T120000_SOUTHERN_ALASKA/SAC/2006-01-28T120000_SOUTHERN_ALASKA.AV.AU12..HHN.sac
# 	./data/seis/2006-01-28T120000_SOUTHERN_ALASKA/SAC/2006-01-28T120000_SOUTHERN_ALASKA.AV.AU13..HHE.sac
# 	./data/seis/2006-01-28T120000_SOUTHERN_ALASKA/SAC/2006-01-28T120000_SOUTHERN_ALASKA.AV.AU13..HHN.sac
# 	./data/seis/2006-01-28T120000_SOUTHERN_ALASKA/SAC/2006-01-28T120000_SOUTHERN_ALASKA.AV.AU14..HHE.sac
# 	./data/seis/2006-01-28T120000_SOUTHERN_ALASKA/SAC/2006-01-28T120000_SOUTHERN_ALASKA.AV.AU14..HHN.sac
# 	./data/seis/2006-01-28T120000_SOUTHERN_ALASKA/SAC/2006-01-28T120000_SOUTHERN_ALASKA.AV.AU15..HHN.sac
# Estimating tilt:
# 	AV.AU11..HHE - 2006-01-11T13:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU11..HHN - 2006-01-11T13:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU12..HHE - 2006-01-11T13:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU12..HHN - 2006-01-11T13:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU13..HHE - 2006-01-11T13:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU13..HHN - 2006-01-11T13:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU14..HHE - 2006-01-11T13:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU14..HHN - 2006-01-11T13:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU11..HHE - 2006-01-13T00:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU11..HHN - 2006-01-13T00:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU12..HHE - 2006-01-13T00:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU12..HHN - 2006-01-13T00:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU13..HHE - 2006-01-13T00:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU13..HHN - 2006-01-13T00:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU14..HHE - 2006-01-13T00:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU14..HHN - 2006-01-13T00:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU11..HHE - 2006-01-17T15:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU11..HHN - 2006-01-17T15:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU12..HHE - 2006-01-17T15:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU12..HHN - 2006-01-17T15:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU13..HHE - 2006-01-17T15:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU13..HHN - 2006-01-17T15:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU14..HHE - 2006-01-17T15:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU14..HHN - 2006-01-17T15:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU11..HHE - 2006-01-27T12:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU11..HHN - 2006-01-27T12:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU12..HHE - 2006-01-27T12:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU12..HHN - 2006-01-27T12:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU13..HHE - 2006-01-27T12:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU13..HHN - 2006-01-27T12:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU14..HHE - 2006-01-27T12:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU14..HHN - 2006-01-27T12:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter
# 	AV.AU15..HHN - 2006-01-27T12:00:00.000000Z
# 		Passband: 43200.00s to 120.00s
# 		Filter order: 2
# 		Using acausal filter

# %% [markdown]
# ## Load data and plot

# %%
st0 = obspy.read("./data/seis/2006-01-11T140000_SOUTHERN_ALASKA/SAC/tilt*.sac")
st1 = obspy.read("./data/seis/2006-01-14T000000_SOUTHERN_ALASKA/SAC/tilt*.sac")

# %%
events = events.get_events()

# %%
fig = plt.figure(figsize=(6, 1.5), constrained_layout=True)
gs = matplotlib.gridspec.GridSpec(1, 10, figure=fig)

sta = "AU12"

# Events 1-2
ax1 = fig.add_subplot(gs[0,:3])
st0_sub = st0.select(station=sta)
trn = st0_sub.select(channel="HHN")[0]
ax1.plot(trn.times("matplotlib"), trn.data*1e6, "k-", label="HHN")

tre = st0_sub.select(channel="HHE")[0]
ax1.plot(tre.times("matplotlib"), tre.data*1e6, "r-", label="HHE")

for event in events:
    ax1.axvline(event.matplotlib_date, linestyle="--", alpha=0.5)

ax1.grid(False)

ax1.set_xlim(trn.times("matplotlib")[0], trn.times("matplotlib")[-1000])

ax1.xaxis.set_major_locator(matplotlib.dates.MinuteLocator(byminute=[0, 30]))
ax1.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%H:%M"))

ax1.set_ylim(-2.5, 2.5)

ax1.set_xlabel("UTC Time on 11 Jan 2006 (HH:MM)", fontsize=8)

alabel = ax1.annotate(
    "a",
    (.05,.89),
    xycoords="axes fraction",
    fontsize=8,
    bbox=dict(facecolor='white', edgecolor='none', boxstyle='round,pad=0.1')
)

ax1.legend(loc="lower left", frameon=False)

ax1.set_ylabel("Tilt ($\\mu$rad)")


# Events 3-8
ax2 = fig.add_subplot(gs[0,3:])
st1_sub = st1.select(station=sta)
trn = st1_sub.select(channel="HHN")[0]
ax2.plot(trn.times("matplotlib"), trn.data*1e6, "k-", label="HHN")

tre = st1_sub.select(channel="HHE")[0]
ax2.plot(tre.times("matplotlib"), tre.data*1e6, "r-", label="HHE")

for event in events:
    ax2.axvline(event.matplotlib_date, linestyle="--", alpha=0.5)

ax2.grid(False)

ax2.set_xlim(trn.times("matplotlib")[35000], trn.times("matplotlib")[-45000])

ax2.xaxis.set_major_locator(matplotlib.dates.HourLocator(byhour=[0, 6, 12, 18]))
ax2.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%d/%m/%y %H"))\

ax2.set_ylim(-7.5, 7.5)

ax2.set_xlabel("UTC Time (DD/MM/YY HH)")

blabel = ax2.annotate(
    "b",
    (.025,.875),
    xycoords="axes fraction",
    fontsize=8,
    bbox=dict(facecolor='white', edgecolor='none', boxstyle='round,pad=0.1')
)


fig.savefig("figs/augustine_timeseries.pdf", bbox_inches="tight")

alabel.remove()
blabel.remove()
fig.suptitle("AU12")

fig.savefig("figs/png/augustine_timeseries.png", dpi=300, bbox_inches="tight")
